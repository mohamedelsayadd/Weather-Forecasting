# %%
print("hello world")
# Out:
# hello world

# %%
import requests

url = "https://renile-iot.com/api/v1/data/"

params = {
    "data_type": "month_hours",
    "start_time": "2026-06-14 00:00",
    "device_id": "681740b2b2b422389cd7831e",
}

headers = {
    "Authorization": "JWT eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJfaWQiOiI2YTFlOWNiYTdjZThlZDcwYzE4NThiMGUiLCJhY2Nlc3MiOiJhdXRoIiwiaWF0IjoxNzgxNjA3MjUyLCJleHAiOjE3ODE2MDgxNTJ9.tkwPX4nQWnBpiXringE6xvBjOHpXVFMOm-tDUw7rESE",
    "Accept": "application/json",
}

response = requests.get(url, params=params, headers=headers, timeout=30)

print(response.status_code)
response.raise_for_status()

data = response.json()
print(data)
# Out:
# 200
# ...

# %%
import pandas as pd

# timestamps من أول sensor
timestamps = pd.to_datetime(
    data[next(iter(data))]["labels"],
    utc=True
)

df = pd.DataFrame({"timestamp": timestamps})
df["timestamp"] = (
    pd.to_datetime(df["timestamp"], utc=True)
      .dt.tz_localize(None)
)

for sensor_name, sensor_data in data.items():
    df[sensor_name] = [
        float(item["$numberDecimal"])
        for item in sensor_data["data"]
    ]

df.head()
# Out:
#             timestamp        SO2      NO2          CO       O3      PM2_5  \
# 0 2026-06-13 22:00:00  24.000000   8.0000  231.000000  14.0000  50.000000
# 1 2026-06-14 08:00:00  58.750000   7.2500  212.750000  52.0000  35.000000
# 2 2026-06-14 09:00:00  41.500000   7.7500  222.000000  56.5000  30.750000
# 3 2026-06-14 11:00:00   8.000000   9.0000  266.000000  62.0000  25.000000
# 4 2026-06-14 12:00:00   8.854167  12.4375  232.104167  65.3125  21.916667
#
#         PM10  ambient_temp  ambinet_Humi  Weather_Pressure  Wind_Speed  \
# 0  61.000000     27.760000     63.330000       1008.100000    1.360000
# 1  40.000000     33.200000     42.170000       1008.200000    0.425000
# 2  33.750000     33.812500     40.420000       1007.950000    0.345000
# 3  27.000000     36.440000     32.880000       1006.900000    0.100000
# 4  22.729167     37.293958     28.150208       1006.270833    0.780729
#
#    Wind_Direction  Rain_Fall
# 0       348.40000        0.0
# 1       285.20000        0.0
# ...
